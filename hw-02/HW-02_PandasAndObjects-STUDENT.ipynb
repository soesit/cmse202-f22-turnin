# %% [markdown]
# # Homework Assignment #2 (Individual)
# ## Pandas Review and Python Classes

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Sit Soe.</p>
# ### <p style="text-align: right;"> &#9989; soesit.</p>

# %% [markdown]
# ### Goals for this homework assignment
# By the end of this assignment, you should be able to:
# - Write a generalizable class to store data
# - Write subclasses that inherit general variables and methods from a parent class
# - Identify key pieces of information that need to be stored as class variables
# - Write methods that fetch and modify class variables
# - Write a function that instantiates new objects given some initial set of parameters
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# There are **62 points** possible on this assignment. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due in roughly two weeks from now at 11:59 pm on Friday, October 7th.** It should be uploaded into the "Homework Assignments" submission folder for Homework #2.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ---
# ## Part 0: Add to your Git repository to track your progress on your assignment (5 points)
#
# For this assignment, you're going to add it to the `cmse202-f22-turnin` repository you created in class so that you can track your progress on the assignment and preserve the final version that you turn in. In order to do this you need to
#
# **&#9989; Do the following**:
#
# 1. Navigate to your `cmse202-f22-turnin` repository and create a new directory called `hw-02`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 1. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" repository (you should have done this in the previous homework assignment).
#
# **Also important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the notebook, **none of your changes will be tracked**!
#
# If everything went as intended, the file should now show up on your GitHub account in the "`cmse202-f22-turnin`" repository inside the `hw-02` directory that you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. Of course, you can always commit your changes more often than that, if you wish.  It can be good to get into a habit of committing your changes any time you make a significant modification, or when you stop working on the project for a bit.
#
# &#9989; **Do this**: Before you move on, put the command that your instructor should run to clone your repository in the markdown cell below.

# %% [markdown]
# Markdown and LaTeX:  𝛼2

# %% [markdown]
# git clone {repo}

# %% [markdown]
# # Using Classes to Store Data
#
#
# One of the primary ways that classes are used is to organize datasets in a way that is both easy to manipulate and key pieces of information are easily accessible.
#
# For this homework assignment, you will be:
# 1. **Creating your own class to encapsulate a dataset**
# 2. **Using that class to create sub-classes**
# 2. **Applying your class(es) to a real data set by creating object instances**
# 2. **Using your objects to answer a (relatively) simple question of the dataset.**
#
# One of the great benefits of classes is their flexibility; they can be applied to anything. For this assignment, you can do these tasks with any dataset. The tasks listed above have been designed to work with (virtually) any dataset. For folks that have recently taken 201 and used a dataset for their final project, you may want to consider using it for this assignment.
#
#
# The following set of tasks are specifically geared towards the following dataset:
#
# `https://github.com/msu-cmse-courses/cmse202-F22-data/blob/main/HW/Homework_2/netflix_titles.csv`
#
# which [comes from here](https://www.kaggle.com/datasets/shivamb/netflix-shows).
#
# You may complete the following specific tasks for the Netflix dataset, or you may use a different dataset and complete your own version of these tasks for your chosen dataset.

# %% [markdown]
# ## Part 1: Examine your Dataset
#
# #### 1.1 Describing your Dataset (2 Points)
# &#9989; Use Pandas to read in your dataset. Describe the conetents of this dataset (E.g., the column names, what they represent, etc.)

# %%
#Write code here
import pandas as pd

# %%
netflix = pd.read_csv('netflix_titles.csv')
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# This datafile describes different netflix shows or movies, cast, director, release date, etc.

# %% [markdown]
# #### 1.2 Dropping Data Columns (2 Points)
# &#9989; We won't be using the first and last columns of this dataframe, so drop them.

# %%
#Write your code here
#dropped first column using  index_col=0
netflix = netflix.iloc[:, 1:11]
netflix
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 10 columns]

# %% [markdown]
# #### 1.3 Thinking about Organizing Data (2 Points)
#
# &#9989; In order to organize things it is useful to classify them into categories. Imagine that each line of the dataset is an instance of an object(s). How would you organize this dataset using object oriented programming? What would the parent class and its child classes be? Think of the Zoo and Animal classes

# %% [markdown]
# * Have each column be part of a class

# %% [markdown]
# ## Part 2: Creating your (Parent) Class
#
# #### 2.1: Creating the Class (9 Points)
#
# &#9989; Create a class called `Production`. The Class should have the attributes `title`, `release_year`, and `genre`. The class should also have `get` and `set` methods for each of the three attributes.

# %%
#Write your (parent) class here
class Production: 
    
    def __init__(self, title, release_year, genre):
        self.title = title
        self.release_year = release_year
        self.genre = genre
    
    def set_title(self, title):
        self.title = title
        
    def set_release_year(self, release_year):
        self.release_year = release_year
        
    def set_genre(self, genre):
        self.genre = genre
        
    def get_title(self):
        return self.title
    
    def get_release_year(self):
        return self.release_year
    
    def get_genre(self):
        return self.genre

# %% [markdown]
# #### 2.2: Testing the Class (2 Points)
#
# &#9989; Select a random entry in the dataset and turn it into a `Production` class object. Print out the title and release year to make sure it is working correctly.

# %%
#Write your code here
random = netflix.iloc[8804,:]


zombie_land = Production(random['title'], random['release_year'], random['listed_in'])
# zombie_land.set_title('Zombieland')
# zombie_land.set_release_year(2009)

print('The movie {0} was released in {1}' .format(zombie_land.get_title(), zombie_land.get_release_year()))
# Out:
# The movie Zombieland was released in 2009

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ## Part 3: Creating your (Child) Classes
#
# #### 3.1 Making the Child Classes (12 Points)
#
# &#9989; Create child classes `Movie` and `TV_Show`. The `Movie` child class should have the added attribute `director` and the `TV_Show` subclass should have the attribute `seasons`. Make sure that each of the child classes has an `__init__` function that takes all of the necessary information to create an instance of that class.
#
# **Note:** Your child classes should use the `super()` function.

# %%
#Write your (child) classes here
class Movie(Production):
    
    def __init__(self, title, release_year, genre, director ):
        self.director = director
        
        super().__init__(title, release_year, genre)
        #Inherets the super class
        
    def set_director(self, director):
        self.director = director
    
    def get_director(self):
        return self.director
    
  
        
   
    
  
        
        
        
class tv_show(Production):
    
    def __init__(self, title, release_year, genre, season):
        self.season = season
        
        super().__init__(title, release_year, genre)
        
        
    def set_season(self, season):
        self.seasons = seasons
    
    def get_season(self):
        return self.season

# %% [markdown]
# #### 3.2: Testing Child Classes (4 points)
#
# &#9989;  Create an instance of both of your objects to ensure that they're working. Use any entry you like to create your objects. Print the director for the `Movie` and the number of seasons for the `TV_Show`.

# %%
#Write your code here
movie_rndm = netflix.iloc[8802, :]
zodiac = Movie(movie_rndm['title'], movie_rndm['release_year'], 
               movie_rndm['listed_in'], movie_rndm['director'])




show_rndm = netflix.iloc[4, :]
kota = tv_show(show_rndm['title'], show_rndm['release_year'], 
               show_rndm['listed_in'] ,show_rndm['duration'])



# print('The movie Zodiac was directed by {0}' .format(zodiac.get_director()))
# print('The show Kota Factory has {}' .format(kota.get_season()))

print('The movie {0} was directed by {1}' .format(zodiac.get_title(), zodiac.get_director()))

print('The show {0} has {1}' .format(kota.get_title(), kota.get_season()))
# Out:
# The movie Zodiac was directed by David Fincher
# The show Kota Factory has 2 Seasons

# %% [markdown]
# ## Part 4: Creating your Objects
#
# #### 4.1: Make all of the Objects! (6 Points)
#
# &#9989; Write a piece of code that uses your dataset to build a list of `Movie` and a list of `TV_Show` objects.

# %%
#Write your code here

# movies = netflix[netflix['type'] == 'Movie'] #df of movies
# movies_list = movies.values.tolist()

# shows = netflix[netflix['type'] == 'TV Show'] #df of shows
# tv_show_list = shows.values.tolist()

# %%
def make_obj(df):
    
    movie_list=[]
    tv_list=[]
    
    for i in range(df['type'].size):
        loc = df.iloc[i]
        
        if loc['type'] == 'Movie':
            movie_info = Movie(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['director'])
            
            movie_list.append(movie_info)
        
        else:
            show_info = tv_show(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['duration'])
            
            tv_list.append(show_info)
            
    return movie_list, tv_list

# %% [markdown]
# #### 4.2: Make sure the `Movie`s and `TV_Show`s work! (2 Points)
#
# &#9989; To test whether you succesfully created the `Movie` and `TV_Show` objects, print out the titles and genres for the first handful (5-10) of `TV_Show` objects.

# %%
# #Write your code here
# tv_objects = tv_show_list[4:9]
# five_shows = tv_show(tv_objects[0], tv_objects[1], tv_objects[2], tv_objects[3])

# print('{0}' .format(five_shows.get_title(), five_shows.get_genre()))

# %%
mv_obj, tv_obj = make_obj(netflix)

for i in range(5):
    
    print(tv_obj[i].get_title(), tv_obj[i].get_genre())
# Out:
# Blood & Water International TV Shows, TV Dramas, TV Mysteries
# Ganglands Crime TV Shows, International TV Shows, TV Action & Adventure
# Jailbirds New Orleans Docuseries, Reality TV
# Kota Factory International TV Shows, Romantic TV Shows, TV Comedies
# Midnight Mass TV Dramas, TV Horror, TV Mysteries

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ## Part 5: Answering your Question
#
#
# We’re going to answer the question **“How has the number of Drama TV Shows changed over time?”**
#
# To answer this question, we’ll need to look at the `release_year` and `genre` variables for each of our `TV_Show` objects. **But** we have a small problem.
#
# #### 5.1 Identifying the Issue (1 Point)
# &#9989; To see what that is, **print out the `genre` of a random `TV_Show` object.**

# %%
#Write your code here
print('The show {0} is under the genres: {1}' .format(tv_obj[8].get_title(),tv_obj[8].get_genre()))
# Out:
# The show Crime Stories: India Detectives is under the genres: British TV Shows, Crime TV Shows, Docuseries

# %% [markdown]
# We need to be able to group the TV shows based on their genre, but TV shows have multiple genres! We need to be able to break apart these genres.
#
#
# #### 5.2: Fixing the Issue (2 Points)
# &#9989; Write a piece of code that will split apart the `genre` string into a `list` of genres. Make sure your code is working by testing it on the list of genres from the previous problem. *Note: This will involve tools we haven’t talked about in class. Use Google to help you solve this problem!*

# %%
#Write your code here
# def split_genre(df):
#     for i in len(df['listed_in']):

tv_obj[8].get_genre().split(',')
# Out:
# ['British TV Shows', ' Crime TV Shows', ' Docuseries']

# %% [markdown]
# #### 5.3: Applying the Fix to our Class (3 Points)
# &#9989;  Take the code that you wrote in the previous problem and turn it into a method for the `Production` class. Run this method within the `__init__` method so that every `Production` object comes into being with the genres split apart into a list.

# %%
#Write your code here
#Write your (parent) class here
class Production: 
    
    def __init__(self, title, release_year, genre):
        self.title = title
        self.release_year = release_year
        self.genre = self.get_genre_split(genre)
    
    
        
    def set_title(self, title):
        self.title = title
        
    def set_release_year(self, release_year):
        self.release_year = release_year
        
    def set_genre(self, genre):
        self.genre = genre
        
    def get_title(self):
        return self.title
    
    def get_release_year(self):
        return self.release_year
    
    def get_genre(self):
        return self.genre
    
    def get_genre_split(self,genre):
        return genre.split(', ')

# %% [markdown]
# #### 5.4: Rebuilding (1 Point)
#
# &#9989; Rebuild your `Movie` and `TV_Show` objects with this new addition to the `Production` class. NOTE: you will need to rerun your code from Part 3 for this to work.

# %%
type(tv_obj[9].get_genre())
# Out:
# str

# %%
tv_obj[9].get_genre() == 'TV Dramas'
# Out:
# False

# %%
tv_obj[9].get_genre()
if tv_obj[9].get_genre() == ['TV Dramas']:
    print(tv_obj[9].get_genre())

# %%
mv_obj, tv_obj = make_obj(netflix)

for i in range(5):
    
    print(tv_obj[i].get_title(), tv_obj[i].get_genre())
# Out:
# Blood & Water International TV Shows, TV Dramas, TV Mysteries
# Ganglands Crime TV Shows, International TV Shows, TV Action & Adventure
# Jailbirds New Orleans Docuseries, Reality TV
# Kota Factory International TV Shows, Romantic TV Shows, TV Comedies
# Midnight Mass TV Dramas, TV Horror, TV Mysteries

# %%
def make_obj(df):
    
    movie_list=[]
    tv_list=[]
    
    for i in range(df['type'].size):
        loc = df.iloc[i]
        
        if loc['type'] == 'Movie':
            movie_info = Movie(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['director'])
            
            movie_list.append(movie_info)
        
        else:
            show_info = tv_show(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['duration'])
            
            tv_list.append(show_info)
            
    return movie_list, tv_list

# %%
mv_obj_lst, tv_obj_lst = make_obj(netflix) #list of objects

# %%
print(tv_obj_lst)
# Out:
# [<__main__.tv_show object at 0x7f3a80f8b490>, <__main__.tv_show object at 0x7f3a80f8b880>, <__main__.tv_show object at 0x7f3a80f8b3d0>, <__main__.tv_show object at 0x7f3a80f8b220>, <__main__.tv_show object at 0x7f3a80f8ba00>, <__main__.tv_show object at 0x7f3a80f8b4f0>, <__main__.tv_show object at 0x7f3a80f8bdc0>, <__main__.tv_show object at 0x7f3a80f8b700>, <__main__.tv_show object at 0x7f3a80f8bd30>, <__main__.tv_show object at 0x7f3a80f8bee0>, <__main__.tv_show object at 0x7f3a80f8b940>, <__main__.tv_show object at 0x7f3a80f8bdf0>, <__main__.tv_show object at 0x7f3a80f8b9a0>, <__main__.tv_show object at 0x7f3a80fd76a0>, <__main__.tv_show object at 0x7f3a80fd71c0>, <__main__.tv_show object at 0x7f3a80fe8400>, <__main__.tv_show object at 0x7f3a80fe8910>, <__main__.tv_show object at 0x7f3a80fe8370>, <__main__.tv_show object at 0x7f3a80fe87c0>, <__main__.tv_show object at 0x7f3a80fe8430>, <__main__.tv_show object at 0x7f3a80fe8b80>, <__main__.tv_show object at 0x7f3a80fe89d0>, <__main__.tv_show object at 0x7f3a80fe8850>, <__main__.tv_show object at 0x7f3a80fe85b0>, <__main__.tv_show object at 0x7f3a80fe8be0>, <__main__.tv_show object at 0x7f3a80fe8700>, <__main__.tv_show object at 0x7f3a80fe8e20>, <__main__.tv_show object at 0x7f3a80f8ef40>, <__main__.tv_show object at 0x7f3a80f8e040>, <__main__.tv_show object at 0x7f3a80f8e1f0>, <__main__.tv_show object at 0x7f3a80fd77f0>, <__main__.tv_show object at 0x7f3a80f8edf0>, <__main__.tv_show object at 0x7f3a80f8eb80>, <__main__.tv_show object at 0x7f3a80f8e0d0>, <__main__.tv_show object at 0x7f3a80f8e250>, <__main__.tv_show object at 0x7f3a80f8e3d0>, <__main__.tv_show object at 0x7f3a80f8eb50>, <__main__.tv_show object at 0x7f3a80f8e5b0>, <__main__.tv_show object at 0x7f3a80f8e670>, <__main__.tv_show object at 0x7f3a80f8e640>, <__main__.tv_show object at 0x7f3a80f8e760>, <__main__.tv_show object at 0x7f3a80f8e340>, <__main__.tv_show object at 0x7f3a80f8eac0>, <__main__.tv_show object at 0x7f3a80f8ec40>, <__main__.tv_show object at 0x7f3a80f8ec70>, <__main__.tv_show object at 0x7f3a80f8eeb0>, <__main__.tv_show object at 0x7f3a80f8e910>, <__main__.tv_show object at 0x7f3a80f8e730>, <__main__.tv_show object at 0x7f3a80fec970>, <__main__.tv_show object at 0x7f3a80fec160>, <__main__.tv_show object at 0x7f3a80fec400>, <__main__.tv_show object at 0x7f3a80fec430>, <__main__.tv_show object at 0x7f3a80fec730>, <__main__.tv_show object at 0x7f3a80fec7c0>, <__main__.tv_show object at 0x7f3a80fec820>, <__main__.tv_show object at 0x7f3a80fec880>, <__main__.tv_show object at 0x7f3a80fecbe0>, <__main__.tv_show object at 0x7f3a80fec2e0>, <__main__.tv_show object at 0x7f3a80fe88b0>, <__main__.tv_show object at 0x7f3a80fec100>, <__main__.tv_show object at 0x7f3a80fdfdc0>, <__main__.tv_show object at 0x7f3a80f907c0>, <__main__.tv_show object at 0x7f3a80f90220>, <__main__.tv_show object at 0x7f3a80f90c70>, <__main__.tv_show object at 0x7f3a80f90550>, <__main__.tv_show object at 0x7f3a80f908e0>, <__main__.tv_show object at 0x7f3a80f90910>, <__main__.tv_show object at 0x7f3a80f90b50>, <__main__.tv_show object at 0x7f3a80f90fa0>, <__main__.tv_show object at 0x7f3b403d71c0>, <__main__.tv_show object at 0x7f3a80fdfe80>, <__main__.tv_show object at 0x7f3a80f90f70>, <__main__.tv_show object at 0x7f3a80cb21f0>, <__main__.tv_show object at 0x7f3a80cb2fa0>, <__main__.tv_show object at 0x7f3a80cb2310>, <__main__.tv_show object at 0x7f3a80cb25b0>, <__main__.tv_show object at 0x7f3a80cb2760>, <__main__.tv_show object at 0x7f3a80cb2640>, <__main__.tv_show object at 0x7f3a80cb22e0>, <__main__.tv_show object at 0x7f3a80cb29d0>, <__main__.tv_show object at 0x7f3a80cb2a90>, <__main__.tv_show object at 0x7f3a80cb2bb0>, <__main__.tv_show object at 0x7f3a80cb28b0>, <__main__.tv_show object at 0x7f3a80cb2910>, <__main__.tv_show object at 0x7f3a80cb2d00>, <__main__.tv_show object at 0x7f3a80fc9bb0>, <__main__.tv_show object at 0x7f3a80fc9940>, <__main__.tv_show object at 0x7f3a80fc9910>, <__main__.tv_show object at 0x7f3a80fc9 ...

# %% [markdown]
# #### 5.5: Am I the Drama...? (1 Point)
#
# &#9989; Select all of the `TV_Show` objects that have drama as one of their genres.

# %%
#Write your code here
tv_dramas = []

for i in tv_obj_lst:
    if 'TV Dramas' in set(i.genre):
        tv_dramas.append(i) #returning list of objs that have TV dramas

# %%
print(tv_dramas)
# Out:
# [<__main__.tv_show object at 0x7f3a80f8b490>, <__main__.tv_show object at 0x7f3a80f8ba00>, <__main__.tv_show object at 0x7f3a80f8bee0>, <__main__.tv_show object at 0x7f3a80f8b940>, <__main__.tv_show object at 0x7f3a80fd76a0>, <__main__.tv_show object at 0x7f3a80fe8370>, <__main__.tv_show object at 0x7f3a80fe85b0>, <__main__.tv_show object at 0x7f3a80fe8be0>, <__main__.tv_show object at 0x7f3a80f8e1f0>, <__main__.tv_show object at 0x7f3a80f8e250>, <__main__.tv_show object at 0x7f3a80f8e640>, <__main__.tv_show object at 0x7f3a80f8ec40>, <__main__.tv_show object at 0x7f3a80fec970>, <__main__.tv_show object at 0x7f3b403d71c0>, <__main__.tv_show object at 0x7f3a80fdfe80>, <__main__.tv_show object at 0x7f3a80cb21f0>, <__main__.tv_show object at 0x7f3a80cb2fa0>, <__main__.tv_show object at 0x7f3a80cb22e0>, <__main__.tv_show object at 0x7f3a80cb2bb0>, <__main__.tv_show object at 0x7f3a80cb28b0>, <__main__.tv_show object at 0x7f3a80fc9bb0>, <__main__.tv_show object at 0x7f3a80fc97f0>, <__main__.tv_show object at 0x7f3a80e83520>, <__main__.tv_show object at 0x7f3a80e7c880>, <__main__.tv_show object at 0x7f3a80e7c490>, <__main__.tv_show object at 0x7f3a80e7c4c0>, <__main__.tv_show object at 0x7f3a80e7c160>, <__main__.tv_show object at 0x7f3a80cb4400>, <__main__.tv_show object at 0x7f3a80cb4be0>, <__main__.tv_show object at 0x7f3a80cb46d0>, <__main__.tv_show object at 0x7f3a80cb43d0>, <__main__.tv_show object at 0x7f3a80eb6190>, <__main__.tv_show object at 0x7f3a80e6e460>, <__main__.tv_show object at 0x7f3a80e6e0d0>, <__main__.tv_show object at 0x7f3a80e6e7f0>, <__main__.tv_show object at 0x7f3a80e6ebb0>, <__main__.tv_show object at 0x7f3a80e6ec10>, <__main__.tv_show object at 0x7f3a80e729a0>, <__main__.tv_show object at 0x7f3a80e776a0>, <__main__.tv_show object at 0x7f3a80e77d60>, <__main__.tv_show object at 0x7f3a80e77dc0>, <__main__.tv_show object at 0x7f3a80f92040>, <__main__.tv_show object at 0x7f3a80f92b80>, <__main__.tv_show object at 0x7f3a80f920a0>, <__main__.tv_show object at 0x7f3a80f92340>, <__main__.tv_show object at 0x7f3a80f924c0>, <__main__.tv_show object at 0x7f3a80f92a60>, <__main__.tv_show object at 0x7f3a80f980a0>, <__main__.tv_show object at 0x7f3a80f982e0>, <__main__.tv_show object at 0x7f3a80f984c0>, <__main__.tv_show object at 0x7f3a80f987c0>, <__main__.tv_show object at 0x7f3a80f98880>, <__main__.tv_show object at 0x7f3a80f98a60>, <__main__.tv_show object at 0x7f3a80f9df10>, <__main__.tv_show object at 0x7f3a80fa2af0>, <__main__.tv_show object at 0x7f3a80fa2be0>, <__main__.tv_show object at 0x7f3a80fa2d00>, <__main__.tv_show object at 0x7f3a80fa2e80>, <__main__.tv_show object at 0x7f3a80fa20d0>, <__main__.tv_show object at 0x7f3a80fa6280>, <__main__.tv_show object at 0x7f3a80fa62e0>, <__main__.tv_show object at 0x7f3a80fa6340>, <__main__.tv_show object at 0x7f3a80fa63a0>, <__main__.tv_show object at 0x7f3a80fa6460>, <__main__.tv_show object at 0x7f3a80fa6520>, <__main__.tv_show object at 0x7f3a80fa65e0>, <__main__.tv_show object at 0x7f3a80fa6640>, <__main__.tv_show object at 0x7f3a80fa6880>, <__main__.tv_show object at 0x7f3a80fa6940>, <__main__.tv_show object at 0x7f3a80fa6a00>, <__main__.tv_show object at 0x7f3a80fa6a60>, <__main__.tv_show object at 0x7f3a80fa6f40>, <__main__.tv_show object at 0x7f3a80fad100>, <__main__.tv_show object at 0x7f3a80fad220>, <__main__.tv_show object at 0x7f3a80fad3a0>, <__main__.tv_show object at 0x7f3a80fad4c0>, <__main__.tv_show object at 0x7f3a80fadbe0>, <__main__.tv_show object at 0x7f3a80fade20>, <__main__.tv_show object at 0x7f3a80fb2b20>, <__main__.tv_show object at 0x7f3a80fb2f40>, <__main__.tv_show object at 0x7f3a80fb2880>, <__main__.tv_show object at 0x7f3a80fb7460>, <__main__.tv_show object at 0x7f3a80fb7a60>, <__main__.tv_show object at 0x7f3a80fbb1f0>, <__main__.tv_show object at 0x7f3a80fbb4f0>, <__main__.tv_show object at 0x7f3a80fbbbb0>, <__main__.tv_show object at 0x7f3a80fbbc70>, <__main__.tv_show object at 0x7f3a80fbbcd0>, <__main__.tv_show object at 0x7f3a80fbb ...

# %% [markdown]
# #### 5.6: Release Years (1 Point)
#
# &#9989; Use your list of `TV_Show` objects to create a list of all of the release years that Drama TV shows came out.

# %%
all_years = [elem.release_year for elem in tv_dramas]
all_years
# Out:
# [2021,
#  2021,
#  2021,
#  2020,
#  2018,
#  2021,
#  2021,
#  2014,
#  2015,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2002,
#  2021,
#  2016,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2019,
#  2021,
#  2021,
#  2009,
#  2010,
#  2021,
#  2021,
#  2021,
#  2019,
#  2020,
#  2019,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2016,
#  2018,
#  2021,
#  2019,
#  2019,
#  2021,
#  2021,
#  2021,
#  2020,
#  2019,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2018,
#  2021,
#  2018,
#  2019,
#  2020,
#  2015,
#  2018,
#  2019,
#  2019,
#  2018,
#  2018,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2015,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2018,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2006,
#  2018,
#  2015,
#  2021,
#  2018,
#  2021,
#  2019,
#  2020,
#  2020,
#  2021,
#  2021,
#  2021,
#  2015,
#  2018,
#  2018,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2019,
#  2020,
#  2021,
#  2021,
#  2019,
#  2019,
#  2021,
#  2021,
#  2018,
#  2020,
#  2020,
#  2021,
#  2017,
#  2021,
#  2019,
#  2019,
#  2020,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2019,
#  2019,
#  2018,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  1999,
#  2020,
#  2017,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2018,
#  2020,
#  2020,
#  2002,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2009,
#  2019,
#  2018,
#  2020,
#  2019,
#  2020,
#  2019,
#  2020,
#  2020,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2017,
#  2020,
#  2020,
#  2012,
#  2020,
#  2020,
#  2020,
#  2016,
#  2020,
#  2014,
#  2020,
#  2020,
#  2016,
#  2020,
#  2018,
#  2019,
#  2020,
#  2020,
#  2020,
#  2019,
#  2020,
#  2020,
#  2016,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2018,
#  2020,
#  2016,
#  2014,
#  2018,
#  2019,
#  2020,
#  2020,
#  2020,
#  2019,
#  2020,
#  2019,
#  2020,
#  2020,
#  2020,
#  2019,
#  2019,
#  2019,
#  2020,
#  2020,
#  2017,
#  2019,
#  2020,
#  2019,
#  2013,
#  2019,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2019,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2017,
#  2020,
#  2019,
#  2018,
#  2018,
#  2020,
#  2020,
#  2020,
#  2020,
#  2017,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2019,
#  2019,
#  2020,
#  2017,
#  2020,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2012,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2019,
#  2015,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2002,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2006,
#  2019,
#  2019,
#  2019,
#  2019,
#  2014,
#  2019,
#  2019,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2014,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2017,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2016,
#  2019,
#  2015,
#  2016,
#  2015,
#  2015,
#  2016,
#  2016,
#  2016,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2013,
#  2012,
#  2019,
#  2019,
#  2018,
#  2019,
#  2018,
#  2019,
#  2018,
#  2019,
#  2018,
#  2019,
#  2019,
#  2018,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2018,
#  2018,
#  2018,
#  2018,
#  2016,
#  2016,
#  2019,
#  2018,
#  2015,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2018,
#  2018,
#  2018,
#  2017,
#  2017,
#  2002,
#  2016,
#  2018,
#  2017,
#  2013,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2016,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2016,
#  2018,
#  2018,
#  2018,
#  2017,
#  2018,
#  2017,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2017,
#  2017,
#  2018,
#  2018,
#  2017,
#  2017,
#  2016,
#  2016,
#  2016,
#  2017,
#  2018,
#  2017,
#  2018,
#  2018,
#  2016,
#  2017,
#  2017,
#  2017,
#  2018,
#  2018,
#  2018,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2017,
#  2015,
#  2017,
#  2016,
#  2015,
#  2015,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2015,
#  2015,
#  2017,
#  2010,
#  2007,
#  2009,
#  2009,
#  2017,
#  2016,
#  2012,
#  2013,
#  2009,
#  2017,
#  2015,
#  2014,
#  2017,
#  2016,
#  2017,
#  2016,
#  2016,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2013,
#  2017,
#  2011,
#  2016,
#  2014,
#  2015,
#  2016,
#  2016,
#  2011,
#  2017,
#  2015,
#  2012,
#  2012,
#  2008,
#  2016,
#  2014,
#  2010,
#  2016,
#  2014,
#  2014,
#  2011,
#  2016,
#  2009,
#  2012,
#  2014,
#  2014,
#  2017,
#  2017,
#  2016,
#  2015,
#  2016,
#  2017,
#  2015,
#  2016,
#  2016,
#  2017,
#  2010,
#  2016,
#  2017,
#  2005,
#  2017,
#  2010,
#  2016,
#  2016,
#  2018,
#  2012,
#  2011,
#  2012,
#  2017,
#  2016,
#  2016,
#  2015,
#  2016,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2010,
#  2016,
#  2016,
#  2016,
#  2015,
#  2014,
#  2013,
#  2007,
#  2013,
#  2018,
#  2013,
#  2018,
#  2013,
#  2013,
#  2015,
#  2010,
#  2017,
#  2015,
#  2012,
#  2013,
#  2016,
#  2017,
#  2015,
#  2016,
#  2015,
#  2010,
#  2016,
#  2015,
#  2016,
#  2018,
#  2014,
#  2016,
#  2013,
#  2016,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2013,
#  2017,
#  2017,
#  2016,
#  2013,
#  2016,
#  2010,
#  2018,
#  2008,
#  2009,
#  2017,
#  2011,
#  2011,
#  2018,
#  2009,
#  2017,
#  2010,
#  2016,
#  2015,
#  2012,
#  2015,
#  2014,
#  2015,
#  2018,
#  1988,
#  2015,
#  2017,
#  2011,
#  2007,
#  2016,
#  2008,
#  2009,
#  2015,
#  2015,
#  2016,
#  2013,
#  2011,
#  2016,
#  2014,
#  2016,
#  2015,
#  2011,
#  2015,
#  2016,
#  2014,
#  2013,
#  2018,
#  2018,
#  2015,
#  2016,
#  2004,
#  2016,
#  2015,
#  2016,
#  2017,
#  2016,
#  2016,
#  2010,
#  2014,
#  2012,
#  2012,
#  2015,
#  2015,
#  2016,
#  2014,
#  2017,
#  2017,
#  2016,
#  2014,
#  2018,
#  1986,
#  2008,
#  2018,
#  2016,
#  2013,
#  2014,
#  2015,
#  2018,
#  1993,
#  2010,
#  2012,
#  2012,
#  2016,
#  2017,
#  2009,
#  2017,
#  2013,
#  2015,
#  2015,
#  2017,
#  2015,
#  2017,
#  2017,
#  2010,
#  2017,
#  2005,
#  2017,
#  2009,
#  2017,
#  1990,
#  2015,
#  2017,
#  2012,
#  2016,
#  2017,
#  2014,
#  2016,
#  2012]

# %% [markdown]
# #### 5.7: Counting the Years (2 Points)
#
# &#9989; Make two lists, one with release years and the other with the number of drama TV shows released during that year. [This page from Stack Overflow](https://stackoverflow.com/questions/2161752/how-to-count-the-frequency-of-the-elements-in-an-unordered-list) may be useful.

# %%
#Write your code here
import collections
counter = collections.Counter(all_years)
years = counter.keys()
frequency = counter.values()

# %% [markdown]
# #### 5.8: It isn't Real Unitl you Make a Plot (2 Points)
#
# &#9989; Make a plot showing the number of dramas versus release year.

# %%
#Write your code here
import matplotlib.pyplot as plt

plt.scatter(years,frequency)
plt.show()

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ### Congratulations, you're done!

# %% [markdown]
# &#169; Copyright 2021,  Department of Computational Mathematics, Science and Engineering at Michigan State University
