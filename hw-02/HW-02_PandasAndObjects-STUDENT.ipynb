# %% [markdown]
# # Homework Assignment #2 (Individual)
# ## Pandas Review and Python Classes

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Sit Soe.</p>
# ### <p style="text-align: right;"> &#9989; soesit.</p>

# %% [markdown]
# ### Goals for this homework assignment
# By the end of this assignment, you should be able to:
# - Write a generalizable class to store data
# - Write subclasses that inherit general variables and methods from a parent class
# - Identify key pieces of information that need to be stored as class variables
# - Write methods that fetch and modify class variables
# - Write a function that instantiates new objects given some initial set of parameters
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# There are **62 points** possible on this assignment. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due in roughly two weeks from now at 11:59 pm on Friday, October 7th.** It should be uploaded into the "Homework Assignments" submission folder for Homework #2.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ---
# ## Part 0: Add to your Git repository to track your progress on your assignment (5 points)
#
# For this assignment, you're going to add it to the `cmse202-f22-turnin` repository you created in class so that you can track your progress on the assignment and preserve the final version that you turn in. In order to do this you need to
#
# **&#9989; Do the following**:
#
# 1. Navigate to your `cmse202-f22-turnin` repository and create a new directory called `hw-02`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 1. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" repository (you should have done this in the previous homework assignment).
#
# **Also important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the notebook, **none of your changes will be tracked**!
#
# If everything went as intended, the file should now show up on your GitHub account in the "`cmse202-f22-turnin`" repository inside the `hw-02` directory that you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. Of course, you can always commit your changes more often than that, if you wish.  It can be good to get into a habit of committing your changes any time you make a significant modification, or when you stop working on the project for a bit.
#
# &#9989; **Do this**: Before you move on, put the command that your instructor should run to clone your repository in the markdown cell below.

# %% [markdown]
# Markdown and LaTeX:  𝛼2

# %% [markdown]
# git clone {repo}

# %% [markdown]
# # Using Classes to Store Data
#
#
# One of the primary ways that classes are used is to organize datasets in a way that is both easy to manipulate and key pieces of information are easily accessible.
#
# For this homework assignment, you will be:
# 1. **Creating your own class to encapsulate a dataset**
# 2. **Using that class to create sub-classes**
# 2. **Applying your class(es) to a real data set by creating object instances**
# 2. **Using your objects to answer a (relatively) simple question of the dataset.**
#
# One of the great benefits of classes is their flexibility; they can be applied to anything. For this assignment, you can do these tasks with any dataset. The tasks listed above have been designed to work with (virtually) any dataset. For folks that have recently taken 201 and used a dataset for their final project, you may want to consider using it for this assignment.
#
#
# The following set of tasks are specifically geared towards the following dataset:
#
# `https://github.com/msu-cmse-courses/cmse202-F22-data/blob/main/HW/Homework_2/netflix_titles.csv`
#
# which [comes from here](https://www.kaggle.com/datasets/shivamb/netflix-shows).
#
# You may complete the following specific tasks for the Netflix dataset, or you may use a different dataset and complete your own version of these tasks for your chosen dataset.

# %% [markdown]
# ## Part 1: Examine your Dataset
#
# #### 1.1 Describing your Dataset (2 Points)
# &#9989; Use Pandas to read in your dataset. Describe the conetents of this dataset (E.g., the column names, what they represent, etc.)

# %%
#Write code here
import pandas as pd

# %%
netflix = pd.read_csv('netflix_titles.csv')
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# This datafile describes different netflix shows or movies, cast, director, release date, etc.

# %% [markdown]
# #### 1.2 Dropping Data Columns (2 Points)
# &#9989; We won't be using the first and last columns of this dataframe, so drop them.

# %%
#Write your code here
#dropped first column using  index_col=0
netflix = netflix.iloc[:, 1:11]
netflix
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 10 columns]

# %% [markdown]
# #### 1.3 Thinking about Organizing Data (2 Points)
#
# &#9989; In order to organize things it is useful to classify them into categories. Imagine that each line of the dataset is an instance of an object(s). How would you organize this dataset using object oriented programming? What would the parent class and its child classes be? Think of the Zoo and Animal classes

# %% [markdown]
# * Have each column be part of a class

# %% [markdown]
# ## Part 2: Creating your (Parent) Class
#
# #### 2.1: Creating the Class (9 Points)
#
# &#9989; Create a class called `Production`. The Class should have the attributes `title`, `release_year`, and `genre`. The class should also have `get` and `set` methods for each of the three attributes.

# %%
#Write your (parent) class here
class Production: 
    
    def __init__(self, title, release_year, genre):
        self.title = title
        self.release_year = release_year
        self.genre = genre
    
    def set_title(self, title):
        self.title = title
        
    def set_release_year(self, release_year):
        self.release_year = release_year
        
    def set_genre(self, genre):
        self.genre = genre
        
    def get_title(self):
        return self.title
    
    def get_release_year(self):
        return self.release_year
    
    def get_genre(self):
        return self.genre

# %% [markdown]
# #### 2.2: Testing the Class (2 Points)
#
# &#9989; Select a random entry in the dataset and turn it into a `Production` class object. Print out the title and release year to make sure it is working correctly.

# %%
#Write your code here
random = netflix.iloc[8804,:]


zombie_land = Production(random['title'], random['release_year'], random['listed_in'])
# zombie_land.set_title('Zombieland')
# zombie_land.set_release_year(2009)

print('The movie {0} was released in {1}' .format(zombie_land.get_title(), zombie_land.get_release_year()))
# Out:
# The movie Zombieland was released in 2009

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ## Part 3: Creating your (Child) Classes
#
# #### 3.1 Making the Child Classes (12 Points)
#
# &#9989; Create child classes `Movie` and `TV_Show`. The `Movie` child class should have the added attribute `director` and the `TV_Show` subclass should have the attribute `seasons`. Make sure that each of the child classes has an `__init__` function that takes all of the necessary information to create an instance of that class.
#
# **Note:** Your child classes should use the `super()` function.

# %%
#Write your (child) classes here
class Movie(Production):
    
    def __init__(self, title, release_year, genre, director ):
        self.director = director
        
        super().__init__(title, release_year, genre)
        #Inherets the super class
        
    def set_director(self, director):
        self.director = director
    
    def get_director(self):
        return self.director
    
  
        
   
    
  
        
        
        
class tv_show(Production):
    
    def __init__(self, title, release_year, genre, season):
        self.season = season
        
        super().__init__(title, release_year, genre)
        
        
    def set_season(self, season):
        self.seasons = seasons
    
    def get_season(self):
        return self.season

# %% [markdown]
# #### 3.2: Testing Child Classes (4 points)
#
# &#9989;  Create an instance of both of your objects to ensure that they're working. Use any entry you like to create your objects. Print the director for the `Movie` and the number of seasons for the `TV_Show`.

# %%
#Write your code here
movie_rndm = netflix.iloc[8802, :]
zodiac = Movie(movie_rndm['title'], movie_rndm['release_year'], 
               movie_rndm['listed_in'], movie_rndm['director'])




show_rndm = netflix.iloc[4, :]
kota = tv_show(show_rndm['title'], show_rndm['release_year'], 
               show_rndm['listed_in'] ,show_rndm['duration'])



# print('The movie Zodiac was directed by {0}' .format(zodiac.get_director()))
# print('The show Kota Factory has {}' .format(kota.get_season()))

print('The movie {0} was directed by {1}' .format(zodiac.get_title(), zodiac.get_director()))

print('The show {0} has {1}' .format(kota.get_title(), kota.get_season()))
# Out:
# The movie Zodiac was directed by David Fincher
# The show Kota Factory has 2 Seasons

# %% [markdown]
# ## Part 4: Creating your Objects
#
# #### 4.1: Make all of the Objects! (6 Points)
#
# &#9989; Write a piece of code that uses your dataset to build a list of `Movie` and a list of `TV_Show` objects.

# %%
#Write your code here

# movies = netflix[netflix['type'] == 'Movie'] #df of movies
# movies_list = movies.values.tolist()

# shows = netflix[netflix['type'] == 'TV Show'] #df of shows
# tv_show_list = shows.values.tolist()

# %%
def make_obj(df):
    
    movie_list=[]
    tv_list=[]
    
    for i in range(df['type'].size):
        loc = df.iloc[i]
        
        if loc['type'] == 'Movie':
            movie_info = Movie(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['director'])
            
            movie_list.append(movie_info)
        
        else:
            show_info = tv_show(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['duration'])
            
            tv_list.append(show_info)
            
    return movie_list, tv_list

# %% [markdown]
# #### 4.2: Make sure the `Movie`s and `TV_Show`s work! (2 Points)
#
# &#9989; To test whether you succesfully created the `Movie` and `TV_Show` objects, print out the titles and genres for the first handful (5-10) of `TV_Show` objects.

# %%
# #Write your code here
# tv_objects = tv_show_list[4:9]
# five_shows = tv_show(tv_objects[0], tv_objects[1], tv_objects[2], tv_objects[3])

# print('{0}' .format(five_shows.get_title(), five_shows.get_genre()))

# %%
mv_obj, tv_obj = make_obj(netflix)

for i in range(5):
    
    print(tv_obj[i].get_title(), tv_obj[i].get_genre())
# Out:
# Blood & Water International TV Shows, TV Dramas, TV Mysteries
# Ganglands Crime TV Shows, International TV Shows, TV Action & Adventure
# Jailbirds New Orleans Docuseries, Reality TV
# Kota Factory International TV Shows, Romantic TV Shows, TV Comedies
# Midnight Mass TV Dramas, TV Horror, TV Mysteries

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ## Part 5: Answering your Question
#
#
# We’re going to answer the question **“How has the number of Drama TV Shows changed over time?”**
#
# To answer this question, we’ll need to look at the `release_year` and `genre` variables for each of our `TV_Show` objects. **But** we have a small problem.
#
# #### 5.1 Identifying the Issue (1 Point)
# &#9989; To see what that is, **print out the `genre` of a random `TV_Show` object.**

# %%
#Write your code here
print('The show {0} is under the genres: {1}' .format(tv_obj[8].get_title(),tv_obj[8].get_genre()))
# Out:
# The show Crime Stories: India Detectives is under the genres: British TV Shows, Crime TV Shows, Docuseries

# %% [markdown]
# We need to be able to group the TV shows based on their genre, but TV shows have multiple genres! We need to be able to break apart these genres.
#
#
# #### 5.2: Fixing the Issue (2 Points)
# &#9989; Write a piece of code that will split apart the `genre` string into a `list` of genres. Make sure your code is working by testing it on the list of genres from the previous problem. *Note: This will involve tools we haven’t talked about in class. Use Google to help you solve this problem!*

# %%
#Write your code here
# def split_genre(df):
#     for i in len(df['listed_in']):

tv_obj[8].get_genre().split(',')
# Out:
# ['British TV Shows', ' Crime TV Shows', ' Docuseries']

# %% [markdown]
# #### 5.3: Applying the Fix to our Class (3 Points)
# &#9989;  Take the code that you wrote in the previous problem and turn it into a method for the `Production` class. Run this method within the `__init__` method so that every `Production` object comes into being with the genres split apart into a list.

# %%
#Write your code here
#Write your (parent) class here
class Production: 
    
    def __init__(self, title, release_year, genre):
        self.title = title
        self.release_year = release_year
        self.genre = self.get_genre_split(genre)
    
    
        
    def set_title(self, title):
        self.title = title
        
    def set_release_year(self, release_year):
        self.release_year = release_year
        
    def set_genre(self, genre):
        self.genre = genre
        
    def get_title(self):
        return self.title
    
    def get_release_year(self):
        return self.release_year
    
    def get_genre(self):
        return self.genre
    
    def get_genre_split(self,genre):
        return genre.split(', ')

# %% [markdown]
# #### 5.4: Rebuilding (1 Point)
#
# &#9989; Rebuild your `Movie` and `TV_Show` objects with this new addition to the `Production` class. NOTE: you will need to rerun your code from Part 3 for this to work.

# %%
type(tv_obj[9].get_genre())
# Out:
# list

# %%
tv_obj[9].get_genre() == 'TV Dramas'
# Out:
# False

# %%
tv_obj[9].get_genre()
if tv_obj[9].get_genre() == ['TV Dramas']:
    print(tv_obj[9].get_genre())

# %%
mv_obj, tv_obj = make_obj(netflix)

for i in range(5):
    
    print(tv_obj[i].get_title(), tv_obj[i].get_genre())
# Out:
# Blood & Water ['International TV Shows', 'TV Dramas', 'TV Mysteries']
# Ganglands ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure']
# Jailbirds New Orleans ['Docuseries', 'Reality TV']
# Kota Factory ['International TV Shows', 'Romantic TV Shows', 'TV Comedies']
# Midnight Mass ['TV Dramas', 'TV Horror', 'TV Mysteries']

# %%
def make_obj(df):
    
    movie_list=[]
    tv_list=[]
    
    for i in range(df['type'].size):
        loc = df.iloc[i]
        
        if loc['type'] == 'Movie':
            movie_info = Movie(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['director'])
            
            movie_list.append(movie_info)
        
        else:
            show_info = tv_show(loc['title'], loc['release_year'], 
                               loc['listed_in'], loc['duration'])
            
            tv_list.append(show_info)
            
    return movie_list, tv_list

# %%
mv_obj_lst, tv_obj_lst = make_obj(netflix) #list of objects

# %%
print(tv_obj_lst)
# Out:
# [<__main__.tv_show object at 0x7f32d3a9aa60>, <__main__.tv_show object at 0x7f32d3a9a550>, <__main__.tv_show object at 0x7f32d3a9a220>, <__main__.tv_show object at 0x7f32d3a9a7f0>, <__main__.tv_show object at 0x7f32d3a9a700>, <__main__.tv_show object at 0x7f32d3a9a9a0>, <__main__.tv_show object at 0x7f32d3a9aac0>, <__main__.tv_show object at 0x7f32d3a91be0>, <__main__.tv_show object at 0x7f32d3a91250>, <__main__.tv_show object at 0x7f32d3a91550>, <__main__.tv_show object at 0x7f32d3a91520>, <__main__.tv_show object at 0x7f32d3a910a0>, <__main__.tv_show object at 0x7f32d3a919a0>, <__main__.tv_show object at 0x7f32d3a91ee0>, <__main__.tv_show object at 0x7f32d3a91f40>, <__main__.tv_show object at 0x7f32d38e5c40>, <__main__.tv_show object at 0x7f32d38e5610>, <__main__.tv_show object at 0x7f32d38e5550>, <__main__.tv_show object at 0x7f32d38e55e0>, <__main__.tv_show object at 0x7f32d38e53a0>, <__main__.tv_show object at 0x7f32d38e5df0>, <__main__.tv_show object at 0x7f32d38e50d0>, <__main__.tv_show object at 0x7f32d38e5cd0>, <__main__.tv_show object at 0x7f32d38e5970>, <__main__.tv_show object at 0x7f32d38e5a00>, <__main__.tv_show object at 0x7f32d38e5310>, <__main__.tv_show object at 0x7f32d38e5ac0>, <__main__.tv_show object at 0x7f32d38e5fa0>, <__main__.tv_show object at 0x7f32d38e5bb0>, <__main__.tv_show object at 0x7f32d38e5190>, <__main__.tv_show object at 0x7f32d38e5820>, <__main__.tv_show object at 0x7f32d374bf40>, <__main__.tv_show object at 0x7f32d374b430>, <__main__.tv_show object at 0x7f32d374b820>, <__main__.tv_show object at 0x7f32d374b7c0>, <__main__.tv_show object at 0x7f32d374bd90>, <__main__.tv_show object at 0x7f32d374b3d0>, <__main__.tv_show object at 0x7f32d374b850>, <__main__.tv_show object at 0x7f32d374b1c0>, <__main__.tv_show object at 0x7f32d374ba30>, <__main__.tv_show object at 0x7f32d374be50>, <__main__.tv_show object at 0x7f32d374b2e0>, <__main__.tv_show object at 0x7f32d4119d30>, <__main__.tv_show object at 0x7f32d4119d90>, <__main__.tv_show object at 0x7f32d374bf10>, <__main__.tv_show object at 0x7f3390ef3cd0>, <__main__.tv_show object at 0x7f3390ef3c10>, <__main__.tv_show object at 0x7f3390ef9d00>, <__main__.tv_show object at 0x7f32d3aee760>, <__main__.tv_show object at 0x7f32d3aeeca0>, <__main__.tv_show object at 0x7f32d3aee970>, <__main__.tv_show object at 0x7f32d3aee430>, <__main__.tv_show object at 0x7f32d38c4cd0>, <__main__.tv_show object at 0x7f32d38c4580>, <__main__.tv_show object at 0x7f32d38c4c10>, <__main__.tv_show object at 0x7f32d38c4130>, <__main__.tv_show object at 0x7f32d38c42b0>, <__main__.tv_show object at 0x7f32d38c4fd0>, <__main__.tv_show object at 0x7f32d375ffd0>, <__main__.tv_show object at 0x7f32d375fdc0>, <__main__.tv_show object at 0x7f32d375f7c0>, <__main__.tv_show object at 0x7f32d375f790>, <__main__.tv_show object at 0x7f32d375fe20>, <__main__.tv_show object at 0x7f32d375f220>, <__main__.tv_show object at 0x7f32d375ff10>, <__main__.tv_show object at 0x7f32d375f040>, <__main__.tv_show object at 0x7f32d3936c10>, <__main__.tv_show object at 0x7f32d3936970>, <__main__.tv_show object at 0x7f32d39368b0>, <__main__.tv_show object at 0x7f32d3936fa0>, <__main__.tv_show object at 0x7f32d3936e50>, <__main__.tv_show object at 0x7f32d3936cd0>, <__main__.tv_show object at 0x7f32d3a863d0>, <__main__.tv_show object at 0x7f32d2fcb5e0>, <__main__.tv_show object at 0x7f32d2fcb640>, <__main__.tv_show object at 0x7f32d2fcb850>, <__main__.tv_show object at 0x7f32d2fcb880>, <__main__.tv_show object at 0x7f32d2fcb8e0>, <__main__.tv_show object at 0x7f32d2fcb9a0>, <__main__.tv_show object at 0x7f32d2fcba00>, <__main__.tv_show object at 0x7f32d2fcba30>, <__main__.tv_show object at 0x7f32d2fcbac0>, <__main__.tv_show object at 0x7f32d2fcbaf0>, <__main__.tv_show object at 0x7f32d2fcbd60>, <__main__.tv_show object at 0x7f32d2fcbe50>, <__main__.tv_show object at 0x7f32d3771370>, <__main__.tv_show object at 0x7f32d3771250>, <__main__.tv_show object at 0x7f32d3771580>, <__main__.tv_show object at 0x7f32d376a ...

# %% [markdown]
# #### 5.5: Am I the Drama...? (1 Point)
#
# &#9989; Select all of the `TV_Show` objects that have drama as one of their genres.

# %%
#Write your code here
tv_dramas = []

for i in range(len(tv_obj_lst)):
    tv_genres = tv_obj_lst[i].get_genre() #get_genre() returns a list of genre as strings, need dramas 
    for j in range(len(tv_genres)):
#         print('Got here')
        if tv_genres[j] == 'TV Dramas':
            tv_dramas.append(tv_obj_lst[i]) #returning list of objs that have TV dramas
            print('Got here')
# Out:
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here
# Got here

# %%
tv_dramas
# Out:
# [<__main__.tv_show at 0x7f32d3a9aa60>,
#  <__main__.tv_show at 0x7f32d3a9a700>,
#  <__main__.tv_show at 0x7f32d3a91550>,
#  <__main__.tv_show at 0x7f32d3a91520>,
#  <__main__.tv_show at 0x7f32d3a91ee0>,
#  <__main__.tv_show at 0x7f32d38e5550>,
#  <__main__.tv_show at 0x7f32d38e5970>,
#  <__main__.tv_show at 0x7f32d38e5a00>,
#  <__main__.tv_show at 0x7f32d38e5190>,
#  <__main__.tv_show at 0x7f32d374b7c0>,
#  <__main__.tv_show at 0x7f32d374ba30>,
#  <__main__.tv_show at 0x7f32d4119d90>,
#  <__main__.tv_show at 0x7f32d3aee760>,
#  <__main__.tv_show at 0x7f32d3936fa0>,
#  <__main__.tv_show at 0x7f32d3936e50>,
#  <__main__.tv_show at 0x7f32d3a863d0>,
#  <__main__.tv_show at 0x7f32d2fcb5e0>,
#  <__main__.tv_show at 0x7f32d2fcb9a0>,
#  <__main__.tv_show at 0x7f32d32b08e0>,
#  <__main__.tv_show at 0x7f32d32b0b20>,
#  <__main__.tv_show at 0x7f32d3283580>,
#  <__main__.tv_show at 0x7f32d3283760>,
#  <__main__.tv_show at 0x7f32d3283ac0>,
#  <__main__.tv_show at 0x7f32d3287160>,
#  <__main__.tv_show at 0x7f32d3287760>,
#  <__main__.tv_show at 0x7f32d3287d00>,
#  <__main__.tv_show at 0x7f32d3287ee0>,
#  <__main__.tv_show at 0x7f32d328d100>,
#  <__main__.tv_show at 0x7f32d328d1c0>,
#  <__main__.tv_show at 0x7f32d328d220>,
#  <__main__.tv_show at 0x7f32d328d3a0>,
#  <__main__.tv_show at 0x7f32d328d7c0>,
#  <__main__.tv_show at 0x7f32d32933a0>,
#  <__main__.tv_show at 0x7f32d3293580>,
#  <__main__.tv_show at 0x7f32d3293c40>,
#  <__main__.tv_show at 0x7f32d3299340>,
#  <__main__.tv_show at 0x7f32d32993a0>,
#  <__main__.tv_show at 0x7f32d329d580>,
#  <__main__.tv_show at 0x7f32d329d700>,
#  <__main__.tv_show at 0x7f32d329dee0>,
#  <__main__.tv_show at 0x7f32d32902e0>,
#  <__main__.tv_show at 0x7f32d3290640>,
#  <__main__.tv_show at 0x7f32d2fd1220>,
#  <__main__.tv_show at 0x7f32d2fd13a0>,
#  <__main__.tv_show at 0x7f32d2fd1700>,
#  <__main__.tv_show at 0x7f32d2fd17c0>,
#  <__main__.tv_show at 0x7f32d2fd1820>,
#  <__main__.tv_show at 0x7f32d2fd1940>,
#  <__main__.tv_show at 0x7f32d2fd19a0>,
#  <__main__.tv_show at 0x7f32d2fd1b20>,
#  <__main__.tv_show at 0x7f32d2fd1fd0>,
#  <__main__.tv_show at 0x7f32d2fe0400>,
#  <__main__.tv_show at 0x7f32d2fe60a0>,
#  <__main__.tv_show at 0x7f32d2fe6820>,
#  <__main__.tv_show at 0x7f32d2fe68e0>,
#  <__main__.tv_show at 0x7f32d2feb880>,
#  <__main__.tv_show at 0x7f32d2feb8e0>,
#  <__main__.tv_show at 0x7f32d2feba60>,
#  <__main__.tv_show at 0x7f32d2febd00>,
#  <__main__.tv_show at 0x7f32d2febe20>,
#  <__main__.tv_show at 0x7f32d2fef160>,
#  <__main__.tv_show at 0x7f32d2fef1c0>,
#  <__main__.tv_show at 0x7f32d2fef340>,
#  <__main__.tv_show at 0x7f32d2fef460>,
#  <__main__.tv_show at 0x7f32d2fef640>,
#  <__main__.tv_show at 0x7f32d2fefb80>,
#  <__main__.tv_show at 0x7f32d2ff6160>,
#  <__main__.tv_show at 0x7f32d2ff62e0>,
#  <__main__.tv_show at 0x7f32d2ff6640>,
#  <__main__.tv_show at 0x7f32d2ff6880>,
#  <__main__.tv_show at 0x7f32d2ff6be0>,
#  <__main__.tv_show at 0x7f32d2ff6fd0>,
#  <__main__.tv_show at 0x7f32d2ffb070>,
#  <__main__.tv_show at 0x7f32d2ffb160>,
#  <__main__.tv_show at 0x7f32d2ffbd00>,
#  <__main__.tv_show at 0x7f32d2fff160>,
#  <__main__.tv_show at 0x7f32d355a220>,
#  <__main__.tv_show at 0x7f32d355a3a0>,
#  <__main__.tv_show at 0x7f32d355f7c0>,
#  <__main__.tv_show at 0x7f32d355fc40>,
#  <__main__.tv_show at 0x7f32d355fd00>,
#  <__main__.tv_show at 0x7f32d3564ca0>,
#  <__main__.tv_show at 0x7f32d356a2e0>,
#  <__main__.tv_show at 0x7f32d356a6a0>,
#  <__main__.tv_show at 0x7f32d356a8e0>,
#  <__main__.tv_show at 0x7f32d356ab80>,
#  <__main__.tv_show at 0x7f32d356abe0>,
#  <__main__.tv_show at 0x7f32d356ac40>,
#  <__main__.tv_show at 0x7f32d356aca0>,
#  <__main__.tv_show at 0x7f32d356ae20>,
#  <__main__.tv_show at 0x7f32d356f0a0>,
#  <__main__.tv_show at 0x7f32d356f100>,
#  <__main__.tv_show at 0x7f32d356f880>,
#  <__main__.tv_show at 0x7f32d356f940>,
#  <__main__.tv_show at 0x7f32d3575460>,
#  <__main__.tv_show at 0x7f32d3575a00>,
#  <__main__.tv_show at 0x7f32d3575ac0>,
#  <__main__.tv_show at 0x7f32d3575b80>,
#  <__main__.tv_show at 0x7f32d3575be0>,
#  <__main__.tv_show at 0x7f32d3575dc0>,
#  <__main__.tv_show at 0x7f32d3579220>,
#  <__main__.tv_show at 0x7f32d35797c0>,
#  <__main__.tv_show at 0x7f32d3579d60>,
#  <__main__.tv_show at 0x7f32d3579e20>,
#  <__main__.tv_show at 0x7f32d357e160>,
#  <__main__.tv_show at 0x7f32d357e400>,
#  <__main__.tv_show at 0x7f32d357e520>,
#  <__main__.tv_show at 0x7f32d357ebe0>,
#  <__main__.tv_show at 0x7f32d38041c0>,
#  <__main__.tv_show at 0x7f32d3804580>,
#  <__main__.tv_show at 0x7f32d3804880>,
#  <__main__.tv_show at 0x7f32d3804940>,
#  <__main__.tv_show at 0x7f32d3804a60>,
#  <__main__.tv_show at 0x7f32d3804b20>,
#  <__main__.tv_show at 0x7f32d3804f40>,
#  <__main__.tv_show at 0x7f32d3809160>,
#  <__main__.tv_show at 0x7f32d3809700>,
#  <__main__.tv_show at 0x7f32d3809820>,
#  <__main__.tv_show at 0x7f32d3809940>,
#  <__main__.tv_show at 0x7f32d3809ca0>,
#  <__main__.tv_show at 0x7f32d3809d60>,
#  <__main__.tv_show at 0x7f32d3809e80>,
#  <__main__.tv_show at 0x7f32d380f460>,
#  <__main__.tv_show at 0x7f32d380f7c0>,
#  <__main__.tv_show at 0x7f32d380f820>,
#  <__main__.tv_show at 0x7f32d380fac0>,
#  <__main__.tv_show at 0x7f32d380fca0>,
#  <__main__.tv_show at 0x7f32d380ffd0>,
#  <__main__.tv_show at 0x7f32d38150a0>,
#  <__main__.tv_show at 0x7f32d3815400>,
#  <__main__.tv_show at 0x7f32d38154c0>,
#  <__main__.tv_show at 0x7f32d38155e0>,
#  <__main__.tv_show at 0x7f32d3815820>,
#  <__main__.tv_show at 0x7f32d38158e0>,
#  <__main__.tv_show at 0x7f32d3815940>,
#  <__main__.tv_show at 0x7f32d3815a00>,
#  <__main__.tv_show at 0x7f32d3815d00>,
#  <__main__.tv_show at 0x7f32d3819dc0>,
#  <__main__.tv_show at 0x7f32d3819e80>,
#  <__main__.tv_show at 0x7f32d381e100>,
#  <__main__.tv_show at 0x7f32d381e1c0>,
#  <__main__.tv_show at 0x7f32d381e4c0>,
#  <__main__.tv_show at 0x7f32d38240a0>,
#  <__main__.tv_show at 0x7f32d3824340>,
#  <__main__.tv_show at 0x7f32d3824640>,
#  <__main__.tv_show at 0x7f32d3824820>,
#  <__main__.tv_show at 0x7f32d3824a60>,
#  <__main__.tv_show at 0x7f32d3824b80>,
#  <__main__.tv_show at 0x7f32d3824dc0>,
#  <__main__.tv_show at 0x7f32d38294c0>,
#  <__main__.tv_show at 0x7f32d38296a0>,
#  <__main__.tv_show at 0x7f32d3829760>,
#  <__main__.tv_show at 0x7f32d3829940>,
#  <__main__.tv_show at 0x7f32d3829e20>,
#  <__main__.tv_show at 0x7f32d382e880>,
#  <__main__.tv_show at 0x7f32d3834160>,
#  <__main__.tv_show at 0x7f32d38341c0>,
#  <__main__.tv_show at 0x7f32d38343a0>,
#  <__main__.tv_show at 0x7f32d3834520>,
#  <__main__.tv_show at 0x7f32d3834880>,
#  <__main__.tv_show at 0x7f32d3839ca0>,
#  <__main__.tv_show at 0x7f32d3839f40>,
#  <__main__.tv_show at 0x7f32d383d820>,
#  <__main__.tv_show at 0x7f32d383dd00>,
#  <__main__.tv_show at 0x7f32d3783160>,
#  <__main__.tv_show at 0x7f32d37832e0>,
#  <__main__.tv_show at 0x7f32d37836a0>,
#  <__main__.tv_show at 0x7f32d3783a60>,
#  <__main__.tv_show at 0x7f32d3783c40>,
#  <__main__.tv_show at 0x7f32d3788220>,
#  <__main__.tv_show at 0x7f32d37883a0>,
#  <__main__.tv_show at 0x7f32d3788400>,
#  <__main__.tv_show at 0x7f32d3788700>,
#  <__main__.tv_show at 0x7f32d3788d60>,
#  <__main__.tv_show at 0x7f32d378d760>,
#  <__main__.tv_show at 0x7f32d378d8e0>,
#  <__main__.tv_show at 0x7f32d378da60>,
#  <__main__.tv_show at 0x7f32d378dbe0>,
#  <__main__.tv_show at 0x7f32d378dc40>,
#  <__main__.tv_show at 0x7f32d378dee0>,
#  <__main__.tv_show at 0x7f32d37920a0>,
#  <__main__.tv_show at 0x7f32d3792070>,
#  <__main__.tv_show at 0x7f32d37921c0>,
#  <__main__.tv_show at 0x7f32d37922e0>,
#  <__main__.tv_show at 0x7f32d3792340>,
#  <__main__.tv_show at 0x7f32d3792460>,
#  <__main__.tv_show at 0x7f32d3792940>,
#  <__main__.tv_show at 0x7f32d3792ca0>,
#  <__main__.tv_show at 0x7f32d37983a0>,
#  <__main__.tv_show at 0x7f32d3798700>,
#  <__main__.tv_show at 0x7f32d3798a60>,
#  <__main__.tv_show at 0x7f32d3798e80>,
#  <__main__.tv_show at 0x7f32d3798f40>,
#  <__main__.tv_show at 0x7f32d379c0a0>,
#  <__main__.tv_show at 0x7f32d379c100>,
#  <__main__.tv_show at 0x7f32d34db6a0>,
#  <__main__.tv_show at 0x7f32d34db700>,
#  <__main__.tv_show at 0x7f32d34db760>,
#  <__main__.tv_show at 0x7f32d34e02e0>,
#  <__main__.tv_show at 0x7f32d34e0340>,
#  <__main__.tv_show at 0x7f32d34e07c0>,
#  <__main__.tv_show at 0x7f32d34e0b20>,
#  <__main__.tv_show at 0x7f32d34e0e80>,
#  <__main__.tv_show at 0x7f32d34e50a0>,
#  <__main__.tv_show at 0x7f32d34e5880>,
#  <__main__.tv_show at 0x7f32d34e5ac0>,
#  <__main__.tv_show at 0x7f32d34ea0a0>,
#  <__main__.tv_show at 0x7f32d34ea160>,
#  <__main__.tv_show at 0x7f32d34ea760>,
#  <__main__.tv_show at 0x7f32d34f4070>,
#  <__main__.tv_show at 0x7f32d34f4280>,
#  <__main__.tv_show at 0x7f32d34f4340>,
#  <__main__.tv_show at 0x7f32d34f44c0>,
#  <__main__.tv_show at 0x7f32d34f4880>,
#  <__main__.tv_show at 0x7f32d34f48e0>,
#  <__main__.tv_show at 0x7f32d34f4be0>,
#  <__main__.tv_show at 0x7f32d34f9b20>,
#  <__main__.tv_show at 0x7f32d34f9d00>,
#  <__main__.tv_show at 0x7f32d34f9f40>,
#  <__main__.tv_show at 0x7f32d34f9fd0>,
#  <__main__.tv_show at 0x7f32d34ff460>,
#  <__main__.tv_show at 0x7f32d34ff700>,
#  <__main__.tv_show at 0x7f32d34fffd0>,
#  <__main__.tv_show at 0x7f32d3484070>,
#  <__main__.tv_show at 0x7f32d3484340>,
#  <__main__.tv_show at 0x7f32d3484400>,
#  <__main__.tv_show at 0x7f32d3484700>,
#  <__main__.tv_show at 0x7f32d3484fd0>,
#  <__main__.tv_show at 0x7f32d34880a0>,
#  <__main__.tv_show at 0x7f32d3488b20>,
#  <__main__.tv_show at 0x7f32d3488ca0>,
#  <__main__.tv_show at 0x7f32d3488d60>,
#  <__main__.tv_show at 0x7f32d348e580>,
#  <__main__.tv_show at 0x7f32d348e640>,
#  <__main__.tv_show at 0x7f32d348ea60>,
#  <__main__.tv_show at 0x7f32d348eca0>,
#  <__main__.tv_show at 0x7f32d348ed60>,
#  <__main__.tv_show at 0x7f32d34930a0>,
#  <__main__.tv_show at 0x7f32d3493160>,
#  <__main__.tv_show at 0x7f32d3493220>,
#  <__main__.tv_show at 0x7f32d3493460>,
#  <__main__.tv_show at 0x7f32d3493640>,
#  <__main__.tv_show at 0x7f32d3493b80>,
#  <__main__.tv_show at 0x7f32d3493be0>,
#  <__main__.tv_show at 0x7f32d3493e20>,
#  <__main__.tv_show at 0x7f32d3493e80>,
#  <__main__.tv_show at 0x7f32d3493ee0>,
#  <__main__.tv_show at 0x7f32d3493fd0>,
#  <__main__.tv_show at 0x7f32d34983a0>,
#  <__main__.tv_show at 0x7f32d3498760>,
#  <__main__.tv_show at 0x7f32d349d1c0>,
#  <__main__.tv_show at 0x7f32d349d340>,
#  <__main__.tv_show at 0x7f32d349d3a0>,
#  <__main__.tv_show at 0x7f32d349d4c0>,
#  <__main__.tv_show at 0x7f32d349d640>,
#  <__main__.tv_show at 0x7f32d349d820>,
#  <__main__.tv_show at 0x7f32d349ddc0>,
#  <__main__.tv_show at 0x7f32d34a21c0>,
#  <__main__.tv_show at 0x7f32d34a2220>,
#  <__main__.tv_show at 0x7f32d34a2280>,
#  <__main__.tv_show at 0x7f32d34a22e0>,
#  <__main__.tv_show at 0x7f32d34a2340>,
#  <__main__.tv_show at 0x7f32d34a23a0>,
#  <__main__.tv_show at 0x7f32d34a26a0>,
#  <__main__.tv_show at 0x7f32d34a29a0>,
#  <__main__.tv_show at 0x7f32d34a2fd0>,
#  <__main__.tv_show at 0x7f32d34a7100>,
#  <__main__.tv_show at 0x7f32d34a7220>,
#  <__main__.tv_show at 0x7f32d34a79a0>,
#  <__main__.tv_show at 0x7f32d34a7a00>,
#  <__main__.tv_show at 0x7f32d34a7a60>,
#  <__main__.tv_show at 0x7f32d34a7ac0>,
#  <__main__.tv_show at 0x7f32d34a7b80>,
#  <__main__.tv_show at 0x7f32d34a7c40>,
#  <__main__.tv_show at 0x7f32d34a7f40>,
#  <__main__.tv_show at 0x7f32d34ad6a0>,
#  <__main__.tv_show at 0x7f32d34ad700>,
#  <__main__.tv_show at 0x7f32d34ad760>,
#  <__main__.tv_show at 0x7f32d34ad7c0>,
#  <__main__.tv_show at 0x7f32d34ad880>,
#  <__main__.tv_show at 0x7f32d34ad940>,
#  <__main__.tv_show at 0x7f32d34ada00>,
#  <__main__.tv_show at 0x7f32d34adb20>,
#  <__main__.tv_show at 0x7f32d34adbe0>,
#  <__main__.tv_show at 0x7f32d34add60>,
#  <__main__.tv_show at 0x7f32d34ade20>,
#  <__main__.tv_show at 0x7f32d34adee0>,
#  <__main__.tv_show at 0x7f32d34adf40>,
#  <__main__.tv_show at 0x7f32d34adfd0>,
#  <__main__.tv_show at 0x7f32d34b10a0>,
#  <__main__.tv_show at 0x7f32d34b1070>,
#  <__main__.tv_show at 0x7f32d34b1160>,
#  <__main__.tv_show at 0x7f32d34b1280>,
#  <__main__.tv_show at 0x7f32d34b12e0>,
#  <__main__.tv_show at 0x7f32d34b1760>,
#  <__main__.tv_show at 0x7f32d34b1be0>,
#  <__main__.tv_show at 0x7f32d34b1c40>,
#  <__main__.tv_show at 0x7f32d34b1ee0>,
#  <__main__.tv_show at 0x7f32d34b63a0>,
#  <__main__.tv_show at 0x7f32d34b6640>,
#  <__main__.tv_show at 0x7f32d34b66a0>,
#  <__main__.tv_show at 0x7f32d34b6880>,
#  <__main__.tv_show at 0x7f32d34bc7c0>,
#  <__main__.tv_show at 0x7f32d3441220>,
#  <__main__.tv_show at 0x7f32d3441280>,
#  <__main__.tv_show at 0x7f32d3441400>,
#  <__main__.tv_show at 0x7f32d3441e20>,
#  <__main__.tv_show at 0x7f32d34453a0>,
#  <__main__.tv_show at 0x7f32d3445a60>,
#  <__main__.tv_show at 0x7f32d3445d00>,
#  <__main__.tv_show at 0x7f32d34500a0>,
#  <__main__.tv_show at 0x7f32d3450400>,
#  <__main__.tv_show at 0x7f32d3450460>,
#  <__main__.tv_show at 0x7f32d3450520>,
#  <__main__.tv_show at 0x7f32d3450760>,
#  <__main__.tv_show at 0x7f32d3450d00>,
#  <__main__.tv_show at 0x7f32d34552e0>,
#  <__main__.tv_show at 0x7f32d3455880>,
#  <__main__.tv_show at 0x7f32d345b100>,
#  <__main__.tv_show at 0x7f32d345b400>,
#  <__main__.tv_show at 0x7f32d345b7c0>,
#  <__main__.tv_show at 0x7f32d345b820>,
#  <__main__.tv_show at 0x7f32d345bc40>,
#  <__main__.tv_show at 0x7f32d345bd60>,
#  <__main__.tv_show at 0x7f32d345f820>,
#  <__main__.tv_show at 0x7f32d345ffd0>,
#  <__main__.tv_show at 0x7f32d3464400>,
#  <__main__.tv_show at 0x7f32d34646a0>,
#  <__main__.tv_show at 0x7f32d3469580>,
#  <__main__.tv_show at 0x7f32d346e4c0>,
#  <__main__.tv_show at 0x7f32d346e8e0>,
#  <__main__.tv_show at 0x7f32d346eb20>,
#  <__main__.tv_show at 0x7f32d346eb80>,
#  <__main__.tv_show at 0x7f32d34714c0>,
#  <__main__.tv_show at 0x7f32d3471a00>,
#  <__main__.tv_show at 0x7f32d34772e0>,
#  <__main__.tv_show at 0x7f32d347b070>,
#  <__main__.tv_show at 0x7f32d347bb80>,
#  <__main__.tv_show at 0x7f32d347bbe0>,
#  <__main__.tv_show at 0x7f32d34008e0>,
#  <__main__.tv_show at 0x7f32d34066a0>,
#  <__main__.tv_show at 0x7f32d3406a00>,
#  <__main__.tv_show at 0x7f32d3406dc0>,
#  <__main__.tv_show at 0x7f32d340f4c0>,
#  <__main__.tv_show at 0x7f32d340f5e0>,
#  <__main__.tv_show at 0x7f32d34151c0>,
#  <__main__.tv_show at 0x7f32d3415280>,
#  <__main__.tv_show at 0x7f32d3415700>,
#  <__main__.tv_show at 0x7f32d3415b20>,
#  <__main__.tv_show at 0x7f32d3415b80>,
#  <__main__.tv_show at 0x7f32d3415ca0>,
#  <__main__.tv_show at 0x7f32d34192e0>,
#  <__main__.tv_show at 0x7f32d3419b80>,
#  <__main__.tv_show at 0x7f32d3419be0>,
#  <__main__.tv_show at 0x7f32d3419d60>,
#  <__main__.tv_show at 0x7f32d341e220>,
#  <__main__.tv_show at 0x7f32d3424520>,
#  <__main__.tv_show at 0x7f32d3424d60>,
#  <__main__.tv_show at 0x7f32d3428100>,
#  <__main__.tv_show at 0x7f32d3434280>,
#  <__main__.tv_show at 0x7f32d34342e0>,
#  <__main__.tv_show at 0x7f32d34343a0>,
#  <__main__.tv_show at 0x7f32d3434460>,
#  <__main__.tv_show at 0x7f32d3439640>,
#  <__main__.tv_show at 0x7f32d3439be0>,
#  <__main__.tv_show at 0x7f32d3439c40>,
#  <__main__.tv_show at 0x7f32d343e220>,
#  <__main__.tv_show at 0x7f32d343e820>,
#  <__main__.tv_show at 0x7f32d33c3880>,
#  <__main__.tv_show at 0x7f32d33c8400>,
#  <__main__.tv_show at 0x7f32d33c8be0>,
#  <__main__.tv_show at 0x7f32d33cd400>,
#  <__main__.tv_show at 0x7f32d33cd7c0>,
#  <__main__.tv_show at 0x7f32d33cdd00>,
#  <__main__.tv_show at 0x7f32d33d3940>,
#  <__main__.tv_show at 0x7f32d33d3e80>,
#  <__main__.tv_show at 0x7f32d33d7ac0>,
#  <__main__.tv_show at 0x7f32d33d7c40>,
#  <__main__.tv_show at 0x7f32d33dc2e0>,
#  <__main__.tv_show at 0x7f32d33dc8e0>,
#  <__main__.tv_show at 0x7f32d33dce20>,
#  <__main__.tv_show at 0x7f32d33dcee0>,
#  <__main__.tv_show at 0x7f32d33e23a0>,
#  <__main__.tv_show at 0x7f32d33e7220>,
#  <__main__.tv_show at 0x7f32d33e76a0>,
#  <__main__.tv_show at 0x7f32d33e7760>,
#  <__main__.tv_show at 0x7f32d33eb160>,
#  <__main__.tv_show at 0x7f32d33eb400>,
#  <__main__.tv_show at 0x7f32d33ebdc0>,
#  <__main__.tv_show at 0x7f32d33f11c0>,
#  <__main__.tv_show at 0x7f32d33f1880>,
#  <__main__.tv_show at 0x7f32d33f6fd0>,
#  <__main__.tv_show at 0x7f32d33fba00>,
#  <__main__.tv_show at 0x7f32d33fbee0>,
#  <__main__.tv_show at 0x7f32d3381070>,
#  <__main__.tv_show at 0x7f32d33814c0>,
#  <__main__.tv_show at 0x7f32d3381580>,
#  <__main__.tv_show at 0x7f32d33815e0>,
#  <__main__.tv_show at 0x7f32d33865e0>,
#  <__main__.tv_show at 0x7f32d33866a0>,
#  <__main__.tv_show at 0x7f32d338a100>,
#  <__main__.tv_show at 0x7f32d338aca0>,
#  <__main__.tv_show at 0x7f32d3390070>,
#  <__main__.tv_show at 0x7f32d3390400>,
#  <__main__.tv_show at 0x7f32d33904c0>,
#  <__main__.tv_show at 0x7f32d339a1c0>,
#  <__main__.tv_show at 0x7f32d339a460>,
#  <__main__.tv_show at 0x7f32d339ab80>,
#  <__main__.tv_show at 0x7f32d339f220>,
#  <__main__.tv_show at 0x7f32d339fb20>,
#  <__main__.tv_show at 0x7f32d33a4940>,
#  <__main__.tv_show at 0x7f32d33a49a0>,
#  <__main__.tv_show at 0x7f32d33b9160>,
#  <__main__.tv_show at 0x7f32d33b92e0>,
#  <__main__.tv_show at 0x7f32d33b9ca0>,
#  <__main__.tv_show at 0x7f32d33b9e80>,
#  <__main__.tv_show at 0x7f32d33be0a0>,
#  <__main__.tv_show at 0x7f32d33be340>,
#  <__main__.tv_show at 0x7f32d33483a0>,
#  <__main__.tv_show at 0x7f32d3348520>,
#  <__main__.tv_show at 0x7f32d334d070>,
#  <__main__.tv_show at 0x7f32d3352280>,
#  <__main__.tv_show at 0x7f32d33525e0>,
#  <__main__.tv_show at 0x7f32d3352ac0>,
#  <__main__.tv_show at 0x7f32d3352d60>,
#  <__main__.tv_show at 0x7f32d3352e80>,
#  <__main__.tv_show at 0x7f32d33560a0>,
#  <__main__.tv_show at 0x7f32d3356580>,
#  <__main__.tv_show at 0x7f32d33567c0>,
#  <__main__.tv_show at 0x7f32d3356ac0>,
#  <__main__.tv_show at 0x7f32d335c4c0>,
#  <__main__.tv_show at 0x7f32d335cd00>,
#  <__main__.tv_show at 0x7f32d3361a60>,
#  <__main__.tv_show at 0x7f32d33669a0>,
#  <__main__.tv_show at 0x7f32d336c460>,
#  <__main__.tv_show at 0x7f32d336c4c0>,
#  <__main__.tv_show at 0x7f32d3370280>,
#  <__main__.tv_show at 0x7f32d33704c0>,
#  <__main__.tv_show at 0x7f32d3370be0>,
#  <__main__.tv_show at 0x7f32d3370ca0>,
#  <__main__.tv_show at 0x7f32d337b070>,
#  <__main__.tv_show at 0x7f32d337b4c0>,
#  <__main__.tv_show at 0x7f32d3300100>,
#  <__main__.tv_show at 0x7f32d3300ac0>,
#  <__main__.tv_show at 0x7f32d330abe0>,
#  <__main__.tv_show at 0x7f32d330af40>,
#  <__main__.tv_show at 0x7f32d330e2e0>,
#  <__main__.tv_show at 0x7f32d3313c40>,
#  <__main__.tv_show at 0x7f32d3313ca0>,
#  <__main__.tv_show at 0x7f32d33191c0>,
#  <__main__.tv_show at 0x7f32d33193a0>,
#  <__main__.tv_show at 0x7f32d3319ca0>,
#  <__main__.tv_show at 0x7f32d3319fd0>,
#  <__main__.tv_show at 0x7f32d3323400>,
#  <__main__.tv_show at 0x7f32d3323700>,
#  <__main__.tv_show at 0x7f32d3323e80>,
#  <__main__.tv_show at 0x7f32d33299a0>,
#  <__main__.tv_show at 0x7f32d3329b80>,
#  <__main__.tv_show at 0x7f32d332d070>,
#  <__main__.tv_show at 0x7f32d332dc40>,
#  <__main__.tv_show at 0x7f32d332ddc0>,
#  <__main__.tv_show at 0x7f32d3332d60>,
#  <__main__.tv_show at 0x7f32d33381c0>,
#  <__main__.tv_show at 0x7f32d3338520>,
#  <__main__.tv_show at 0x7f32d333d340>,
#  <__main__.tv_show at 0x7f32d333dac0>,
#  <__main__.tv_show at 0x7f32d333de80>,
#  <__main__.tv_show at 0x7f32d32c1100>,
#  <__main__.tv_show at 0x7f32d32c19a0>,
#  <__main__.tv_show at 0x7f32d32c7b80>,
#  <__main__.tv_show at 0x7f32d32c7d00>]

# %% [markdown]
# #### 5.6: Release Years (1 Point)
#
# &#9989; Use your list of `TV_Show` objects to create a list of all of the release years that Drama TV shows came out.

# %%
#Write your code here

# %% [markdown]
# #### 5.7: Counting the Years (2 Points)
#
# &#9989; Make two lists, one with release years and the other with the number of drama TV shows released during that year. [This page from Stack Overflow](https://stackoverflow.com/questions/2161752/how-to-count-the-frequency-of-the-elements-in-an-unordered-list) may be useful.

# %%
#Write your code here

# %% [markdown]
# #### 5.8: It isn't Real Unitl you Make a Plot (2 Points)
#
# &#9989; Make a plot showing the number of dramas versus release year.

# %%
#Write your code here

# %% [markdown]
# ---
# ### &#128721; STOP (1 Point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit the changes to your Git repository. Merge the changes in the main branch, and push the changes to GitHub.
#
# ---

# %% [markdown]
# ### Congratulations, you're done!

# %% [markdown]
# &#169; Copyright 2021,  Department of Computational Mathematics, Science and Engineering at Michigan State University
